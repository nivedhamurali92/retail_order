# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import pandas as pd
df = pd.read_csv("orders.csv.zip")
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
df=pd.read_csv('orders.csv.zip',na_values=['Not available','unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', nan,
#        'First Class', 'Same Day'], dtype=object)

# %%
df.rename(columns={'Order Id':'order_id', 'City':'city'})
# Out:
#       order_id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       State  Postal Code Region         Category  \
# ...

# %%
df.dtypes
# Out:
# Order Id             int64
# Order Date          object
# Ship Mode           object
# Segment             object
# Country             object
# City                object
# State               object
# Postal Code          int64
# Region              object
# Category            object
# Sub Category        object
# Product Id          object
# cost price           int64
# List Price           int64
# Quantity             int64
# Discount Percent     int64
# dtype: object

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.dtypes
# Out:
# Order_Id             int64
# Order_Date          object
# Ship_Mode           object
# Segment             object
# Country             object
# City                object
# State               object
# Postal_Code          int64
# Region              object
# Category            object
# Sub_Category        object
# Product_Id          object
# cost_price           int64
# List_Price           int64
# Quantity             int64
# Discount_Percent     int64
# dtype: object

# %%
df['discount']=df['List_Price']*df['Discount_Percent']*.01

# %%
df['sales_Price']=df['List_Price']-df['discount']

# %%
df['profit']=df['sales_Price']-df['cost_price']

# %%
df
# Out:
#       Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# ...

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df.dtypes
# Out:
# Order_Id                     int64
# Order_Date          datetime64[ns]
# Ship_Mode                   object
# Segment                     object
# Country                     object
# City                        object
# State                       object
# Postal_Code                  int64
# Region                      object
# Category                    object
# Sub_Category                object
# Product_Id                  object
# cost_price                   int64
# List_Price                   int64
# Quantity                     int64
# Discount_Percent             int64
# discount                   float64
# sales_Price                float64
# profit                     float64
# dtype: object

# %%
df1=df.iloc[:,:10]

# %%
df2=df.iloc[:,10:]

# %%
df1.dtypes
# Out:
# Order_Id                int64
# Order_Date     datetime64[ns]
# Ship_Mode              object
# Segment                object
# Country                object
# City                   object
# State                  object
# Postal_Code             int64
# Region                 object
# Category               object
# dtype: object

# %%
df['Ship_Mode']=df['Ship_Mode'].str.rstrip()

# %%
df['Segment']=df['Segment'].str.rstrip()

# %%
df['Country']=df['Country'].str.rstrip()

# %%
df['City']=df['City'].str.rstrip()

# %%
df['State']=df['State'].str.rstrip()

# %%
df['Region']=df['Region'].str.rstrip()

# %%
df['Category']=df['Category'].str.rstrip()

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
order=df

# %%
order
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df2
# Out:
#      Sub_Category       Product_Id  cost_price  List_Price  Quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       Discount_Percent  discount  sales_Price  profit
# 0                    2       5.2        254.8    14.8
# ...

# %%
db_config ={
    'host':'localhost',
     'user':'root',
      'password':'kasthuri67' 
}

# %%
df1
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df1.dtypes
# Out:
# Order_Id                int64
# Order_Date     datetime64[ns]
# Ship_Mode              object
# Segment                object
# Country                object
# City                   object
# State                  object
# Postal_Code             int64
# Region                 object
# Category               object
# dtype: object

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conn = pymysql.connect(**db_config)
cursor=conn.cursor()

# %%
cursor.execute("create database if not exists retail_orders")
# Out:
# 1

# %%
import pymysql

# %%
cursor.execute("use retail_orders")
# Out:
# 0

# %% [raw]
# cursor.execute("Create table if not exists df_orders( Order_Id int,Order_Date date,Ship_Mode varchar(20),Segment varchar(20),Country varchar(20),City varchar(20),State varchar(20),Postal_Code int,Region varchar(20),Category varchar(20)"))

# %%
cursor.execute("create table if not exists order_guvi( Order_Id int,Order_Date date,Ship_Mode varchar(20),Segment varchar(20),Country varchar(20),City varchar(20),State varchar(20),Postal_Code int,Region varchar(20),Category varchar(20),Sub_Category varchar(20),Product_Id text,	cost_price int,	List_Price int,	Quantity int,	Discount_Percent int,	discount int,	sales_Price int,	profit int)"),
# Out:
# (0,)

# %%
insert_query="""INSERT INTO order_guvi(Order_Id ,Order_Date ,Ship_Mode,Segment,Country ,City ,State,Postal_Code,Region ,Category ,Sub_Category,Product_Id ,	cost_price ,	List_Price,	Quantity ,	Discount_Percent,	discount ,	sales_Price ,	profit)values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""

# %%
for index, row in df.iterrows():
    cursor.execute(insert_query,(row["Order_Id"] ,row["Order_Date"],row["Ship_Mode"],row["Segment"],row["Country"] ,row["City"],row["State"],row["Postal_Code"],row["Region"] ,row["Category"],
        row["Sub_Category"], row["Product_Id"], row["cost_price"], row["List_Price"],
        row["Quantity"], row["Discount_Percent"], row["discount"], row["sales_Price"],
        row["profit"]))

# %%
conn.commit()

# %%
df=df.where(pd.notnull(df),None)

# %%
import mysql.connector
